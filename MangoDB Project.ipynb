# %% [markdown]
# # MONGODB

# %% [markdown]
# Dans cet exercice, on souhaite modéliser les ressources humaines d’une entreprise.
# Ces données seront essentiellement utilisées pour identifier l’activité d’un employé autour de son expertise et des entreprises auprès desquelles il intervient.
# Vous disposez du diagramme Entité-Association suivant :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Le modéle physique retenu est le suivant :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q1 - Créer une base de données RH (1 pt)

# %% [raw]
# # Lancer mongo container
# docker start mongo
# # Lancer mongo bash
# docker exec -it mongo bash
# mongo

# %% [raw]
# # Creation de la base de données "RH"
# use RH

# %% [markdown]
# Q2 - Créer dans la base de données RH, les collections du modéle décrit ci-dessus  en vous appuyant des données ci-dessous :
#
# * Steven King né le 01/05/1956 habite au 1 bd Haussmann à Paris,expert en PYTHON , SPARK , ORACLE et travaille depuis le 03/04/2000 au CNRS(Rome)
#
# * Neena Kochhar né le 11/03/1980 habite 3091 Calle della Testa à Venise, expert en JAVA et travaille depuis le 18/05/2016 chez EDF(Venise).
#
# * Lex Dehaan né le 11/02/1950 habite au 9450 Kamiya-cho à Hiroshima, expert en SQL et travaille depuis le 21/01/2015 chez Air France (Hiroshima)
#
# * Alexander Hunold né le 07/07/1958 habite au 20 Rue des Corps-Saints à Geneve,  expert en XML, HADOOP, PHP et travaille depuis le 12/11/2020 au CERN (Geneve)
#
# * Bruce Ernst né le 17/08/1968 habite au 1360 Rua Frei Caneca à Sao Paulo, expert en MYSQL, SCALA, KAFKA et travaille depuis le 16/02/2018 chez ATOS (Sao Paulo)
#
# Vous indiquerez ci-dessous les commandes que vous exécuterez (4 pts) :

# %% [raw]
# # Creation des collection
# db.createCollection("Entreprises")
# db.createCollection("Personnes")

# %% [raw]
# # Creation des documents de Entreprises
# db.Entreprises.insertMany([
# {
#     _id: 1,
#     nameE: "CNRS",
#     adresseE: "Rome",
#     description: " "
# },
# {
#     _id: 2,
#     nameE: "EDF",
#     adresseE: "Venise",
#     description: " "
# },
# {
#     _id: 3,
#     nameE: "Air France",
#     adresseE: "Hiroshima",
#     description: " "
# },
# {
#     _id: 4,
#     nameE: "CERN",
#     adresseE: "Geneve",
#     description: " "
# },
# {
#     _id: 5,
#     nameE: "ATOS",
#     adresseE: "Sao Paulo",
#     description: " "
# }
# ])

# %% [raw]
# # Creation des documents dans Personnes
# db.Personnes.insertMany([
#   {
#     _id: 1,
#     nom: "King",
#     prenom: "Steven",
#     dateNaissance: {
#                    jour: 01,
#                    mois: 05,
#                    annee: 1956
#     },
#     habitation: {
#                 adresse: "1 bd Haussmann",
#                 ville: "Paris"
#     },
#     domaines: {
#               name: ["PYTHON" , "SPARK" , "ORACLE"]
#     },
#     embaucher: {
#                id_ent: 1,
#                dateEmbauche: "03/04/2000"
#     }
#   },
#   {
#     _id: 2,
#     nom: "Kochhar",
#     prenom: "Neena",
#     dateNaissance: {
#                     jour: 11,
#                     mois: 03,
#                     annee: 1980
#     },
#     habitation: {
#                 adresse: "3091 Calle della Testa",
#                 ville: "Venise"
#     },
#     domaines: {
#               name: ["JAVA"]
#     },
#     embaucher: {
#                id_ent: 2,
#                dateEmbauche: "18/05/2016"
#     }
#   },
#   {
#     _id: 3,
#     nom: "Dehaan",
#     prenom: "Lex",
#     dateNaissance: {
#                    jour: 11,
#                    mois: 02,
#                    annee: 1950
#     },
#     habitation: {
#                 adresse: "9450 Kamiya-cho",
#                 ville: "Hiroshima"
#     },
#     domaines: {
#               name: ["SQL"]
#     },
#     embaucher: {
#                id_ent: 3,
#                dateEmbauche: "21/01/2015"
#     }
#   },
#   {
#     _id: 4,
#     nom: "Hunold",
#     prenom: "Alexander",
#     dateNaissance: {
#                    jour: 07,
#                    mois: 07,
#                    annee: 1958
#     },
#     habitation: {
#                 adresse: "20 Rue des Corps-Saints",
#                 ville: "Geneve"
#     },
#     domaines: {
#               name: ["XML", "HADOOP", "PHP"]
#     },
#     embaucher: {
#                id_ent: 4,
#                dateEmbauche: "12/11/2020"
#     }
#   },
#   {
#     _id: 5,
#     nom: "Ernst",
#     prenom: "Bruce",
#     dateNaissance: {
#                    jour: 17,
#                    mois: 08,
#                    annee: 1968
#     },
#     habitation: {
#                 adresse: "1360 Rua Frei Caneca",
#                 ville: "Sao Paulo"
#     },
#     domaines: {
#               name: ["MYSQL", "SCALA", "KAFKA"]
#     },
#     embaucher: {
#                id_ent: 5,
#                dateEmbauche: "16/02/2018"
#     }
#   }
# ])

# %% [markdown]
# Q3 - Sélectionner le nom, prénom, la ville du domicile et les domaines d'expertise des personnes né entre 1920 et 1960 ? (1 pt)

# %% [raw]
# db.Personnes.find({"dateNaissance.annee": {$gt: 1920, $lt: 1960}}, {"_id":0, "nom":1, "prenom":1, "habitation.ville":1, "domaines.name":1})

# %% [markdown]
# Q4 - Indiquez l'ordre mongo qui vous permettra d'ajouter la compétence 'NEO4J' à Bruce Ernst. (2 pts)

# %% [raw]
# db.Personnes.updateOne({"nom": "Ernst", "prenom": "Bruce"}, {$push: {"domaines.name": "NEO4J"}})

# %% [markdown]
# Q5 - Compter le nombre de personne par expertise/domaine ? (2 pts)

# %% [raw]
# db.Personnes.aggregate([
# {$unwind: "$domaines.name"},
# {$group : {_id:"$domaines.name", count:{$sum:1}}}
# ])

# %% [markdown]
# Q6 - Indiquer la requête qui vous permettra de trouver l'ensemble des entreprises pour lesquels une personne travaille : (2 pts)

# %% [raw]
# # à titre d'example on cherche les entreprise pour lesquels "Bruce Ernst" travail
#
# db.Personnes.aggregate([
# {$match: {nom: "Ernst", prenom: "Bruce"}},
# {$project: {_id:0, nom:1, prenom:1}},
# {$lookup: {from: "Entreprises", localField: "embaucher.id_ent", foreignField: "_id", "pipeline": [{$project: {"_id":0, "nameE":1}}], as: "Entreprises"}}
# ])

# %% [markdown]
# Q7 - Proposer une solution afin que la structure des documents personnes respectent celle attendue : (5 pts)

# %% [raw]
# # En utilisant un Json Schema :
# {
#     required: ["nom", "prenom"],
#     properties: {
#         nom:{
#             bsontype: "string",
#             description: "Nom de la personne. (Obligatoire)"
#         },
#         prenom:{
#             bsontype: "string",
#             description: "Prenom de la personne. (Obligatoire)"
#         },
#         dateNaissance:{
#             bsontype: "object",
#             required: ["jour", "mois", "annee"]
#             description: "Date de naissance de la personne."
#             properties:{
#                 jour:{
#                     bsontype: "int"
#                 },
#                 mois:{
#                     bsontype: "int"
#                 },
#                 annee:{
#                     bsontype: "int"
#                 }
#             }
#         },
#         habitation:{
#             bsontype: "object",
#             required: ["adresse", "ville"]
#             description: "Adresse de la personne."
#             properties:{
#                 adresse:{
#                     bsontype: "string"
#                 },
#                 ville:{
#                     bsontype: "string"
#                 }
#             }
#         },
#         domaines:{
#             bsontype: "object",
#             description: "Domaines d'expertise de la personne."
#             properties:{
#                 name:{
#                     bsontype: "array",
#                     description: "array contenant les noms des domaines sous forme de string."
#                 }
#             }
#         },
#         embaucher:{
#             bsontype: "object",
#             description: "Etat professionel de la personne."
#             required: ["id_ent"]
#             properties:{
#                 id_ent:{
#                     bsontype: "int",
#                     description: "identifiant de l'entreprise chez laquel la personne est embaucher."
#                 },
#                 dateEmbauche:{
#                     bsontype: "string",
#                     description: "Date de recrutement de la personne."
#                 }
#             }
#         }
#     }
# }

# %% [markdown]
# Q8 - Supprimer à présent l'entreprise ATOS : (1 pt)

# %% [raw]
# db.Entreprises.remove({nameE: "ATOS"})

# %% [markdown]
# Q9 - Quel probléme cela soulève-t'il ? (2 pts)

# %% [raw]
# La personne "Bruce Ernst" est lié à un indice d'entreprise qui n'existe plus.
# Cela donnerai par example un resultat vide si on cherche a trouver l'entrepise chez laquel travail ce dernier avec $lookup.
